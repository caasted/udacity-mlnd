# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.841523
# Nearest to war: flakes, discuss, disorder, piranha, equivalent, durant, preexisting, cool,
# Nearest to its: ambulances, slade, berne, astray, accomplice, ph, kayak, bitters,
# Nearest to been: pashtuns, disputing, reformation, distressing, disperse, telegraphic, threatened, slashed,
# Nearest to state: minas, tiered, kilby, tory, pamplona, weekends, coke, downturn,
# Nearest to this: debbie, deteriorate, lash, worn, moose, pathophysiology, articles, profusion,
# Nearest to they: moor, odie, occitan, odds, gediminas, hoof, laura, langmuir,
# Nearest to had: dowager, grammarian, degeneration, scranton, decorating, however, buell, tatra,
# Nearest to would: discontinuous, volunteered, confidentiality, courses, frankenheimer, hierarchically, encyclopedias, heliocentric,
# Nearest to seven: repudiate, third, fdp, unstressed, zo, squat, progressed, worry,
# Nearest to at: culturally, woogie, hyperactivity, attempt, splendour, pipelines, order, nanotechnology,
# Nearest to it: popularised, scientific, adt, parton, lacanian, reduces, pressure, europeans,
# Nearest to was: computational, rallied, saxony, convergence, thoracic, builders, palmyra, antioxidants,
# Nearest to an: pronouns, earldom, wangenheim, assembler, horseshoes, slums, cessna, rambla,
# Nearest to most: castile, message, axillary, strangeness, expense, hammurabi, satanic, jumo,
# Nearest to from: notated, revisionism, psych, plexus, bandar, nebulous, pentastar, ingestion,
# Nearest to many: diadem, dostoevsky, newbies, randomized, kingdom, appointment, ia, dispatched,
# Average loss at step 2000: 4.359186
# Average loss at step 4000: 3.868494
# Average loss at step 6000: 3.787163
# Average loss at step 8000: 3.692619
# Average loss at step 10000: 3.615910
# Nearest to war: flakes, piranha, disorder, dijkstra, luc, preexisting, conveyed, loon,
# Nearest to its: his, the, their, ambulances, rnir, maiden, castillo, berne,
# Nearest to been: be, was, never, reflectors, were, daring, interfacing, campaigner,
# Nearest to state: minas, hx, kilby, tory, undercarriage, arisen, towards, alloy,
# Nearest to this: it, the, which, making, peppers, pathophysiology, lactamase, eskimo,
# Nearest to they: he, it, not, we, there, odds, moor, sighted,
# Nearest to had: has, was, have, dim, however, tatra, makes, diesel,
# Nearest to would: should, can, must, discontinuous, may, could, tipping, will,
# Nearest to seven: six, eight, four, five, nine, three, two, zero,
# Nearest to at: in, characterizes, by, beautifully, neighborhoods, acknowledgment, from, cardiff,
# Nearest to it: he, this, now, they, there, which, she, not,
# Nearest to was: is, were, by, has, had, be, been, bain,
# Nearest to an: pronouns, targets, sheila, tattoo, the, pioneers, koontz, nw,
# Nearest to most: louth, strangeness, parallel, stabilizing, all, vigilance, workable, some,
# Nearest to from: into, tonle, animism, bandar, in, with, by, at,
# Nearest to many: some, randomized, newbies, dostoevsky, several, memo, caption, enlarged,
# Average loss at step 12000: 3.604561
# Average loss at step 14000: 3.569148
# Average loss at step 16000: 3.407514
# Average loss at step 18000: 3.460323
# Average loss at step 20000: 3.531884
# Nearest to war: flakes, luc, piranha, severus, drowns, loon, dijkstra, disorder,
# Nearest to its: their, his, the, rnir, any, maiden, her, ambulances,
# Nearest to been: be, never, by, were, daring, campaigner, was, lange,
# Nearest to state: minas, hx, arisen, tory, harming, soviet, towards, pamplona,
# Nearest to this: it, which, the, that, a, he, perceptual, tragedians,
# Nearest to they: he, we, there, it, these, who, you, she,
# Nearest to had: has, have, was, were, makes, dim, saw, universiteit,
# Nearest to would: could, may, should, can, will, must, might, to,
# Nearest to seven: eight, six, nine, three, four, five, zero, two,
# Nearest to at: in, from, pipelines, acknowledgment, under, antikythera, on, by,
# Nearest to it: he, there, this, she, they, which, now, contracting,
# Nearest to was: is, were, has, had, be, became, are, but,
# Nearest to an: sheila, the, pronouns, gifford, nw, targets, pioneers, ballets,
# Nearest to most: more, stabilizing, some, many, all, philosophical, vigilance, louth,
# Nearest to from: into, at, in, through, bandar, for, and, with,
# Nearest to many: some, several, these, all, other, dostoevsky, most, randomized,
# Average loss at step 22000: 3.505176
# Average loss at step 24000: 3.491124
# Average loss at step 26000: 3.481227
# Average loss at step 28000: 3.483052
# Average loss at step 30000: 3.509009
# Nearest to war: flakes, carriage, jarring, andrews, match, severus, luc, easter,
# Nearest to its: their, his, the, topeka, maiden, zooplankton, ambulances, wheelers,
# Nearest to been: be, was, never, were, daring, wildstorm, reflectors, had,
# Nearest to state: minas, hx, lr, arisen, result, council, tory, forces,
# Nearest to this: which, it, another, cryptanalytic, that, uda, there, explode,
# Nearest to they: we, there, he, you, these, it, who, she,
# Nearest to had: have, has, was, were, saw, never, would, debtors,
# Nearest to would: can, could, may, should, will, must, might, cannot,
# Nearest to seven: six, nine, eight, four, five, three, zero, two,
# Nearest to at: in, antikythera, luggage, goodman, when, during, round, near,
# Nearest to it: he, there, she, this, they, which, also, now,
# Nearest to was: is, had, were, has, became, been, be, when,
# Nearest to an: sheila, nw, gifford, disjunction, falsehoods, tycho, maureen, targets,
# Nearest to most: some, stabilizing, more, hohlbein, extremely, philosophical, many, chopped,
# Nearest to from: into, in, tonle, under, of, for, by, redefine,
# Nearest to many: some, several, these, all, other, most, enlarged, examples,
# Average loss at step 32000: 3.497253
# Average loss at step 34000: 3.491465
# Average loss at step 36000: 3.453026
# Average loss at step 38000: 3.296595
# Average loss at step 40000: 3.423169
# Nearest to war: jarring, flakes, luc, carriage, loon, match, antiquaries, andrews,
# Nearest to its: their, his, the, her, maiden, topeka, manchurian, wheelers,
# Nearest to been: were, be, become, never, was, daring, wildstorm, had,
# Nearest to state: minas, hx, county, council, states, soviet, economy, beloved,
# Nearest to this: which, it, the, that, another, gh, sonatas, any,
# Nearest to they: we, there, he, you, it, these, she, who,
# Nearest to had: has, have, was, were, never, saw, been, makes,
# Nearest to would: could, will, can, may, should, must, might, cannot,
# Nearest to seven: six, eight, five, nine, four, three, zero, one,
# Nearest to at: in, on, antikythera, minh, courting, luggage, inspirations, ponder,
# Nearest to it: he, she, there, this, they, which, not, vm,
# Nearest to was: is, has, were, had, became, being, been, be,
# Nearest to an: sheila, koontz, medici, gifford, absalon, falsehoods, jamahiriya, gravitons,
# Nearest to most: more, hohlbein, many, stabilizing, among, philosophical, some, extremely,
# Nearest to from: into, of, redefine, in, under, after, presents, myrinet,
# Nearest to many: some, several, these, most, various, smoker, enlarged, other,
# Average loss at step 42000: 3.436320
# Average loss at step 44000: 3.457293
# Average loss at step 46000: 3.451415
# Average loss at step 48000: 3.347987
# Average loss at step 50000: 3.382014
# Nearest to war: jarring, loon, match, flakes, carriage, antiquaries, severus, andrews,
# Nearest to its: their, his, the, her, wheelers, topeka, your, maiden,
# Nearest to been: become, was, be, were, daring, previously, sergey, largely,
# Nearest to state: minas, hx, council, county, alcoholic, states, economy, gens,
# Nearest to this: which, it, the, sonatas, proudly, urging, some, another,
# Nearest to they: we, he, there, you, it, she, who, these,
# Nearest to had: has, have, was, were, having, byproduct, claimed, would,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to seven: six, eight, nine, four, three, five, zero, two,
# Nearest to at: during, on, in, goodman, from, alkyl, woogie, damian,
# Nearest to it: he, there, she, they, this, now, often, not,
# Nearest to was: is, were, became, has, been, be, had, by,
# Nearest to an: nw, sheila, gifford, flare, gravitons, contras, godless, calatrava,
# Nearest to most: more, many, some, hohlbein, extremely, stabilizing, philosophical, criss,
# Nearest to from: into, bandar, through, in, across, under, redefine, myrinet,
# Nearest to many: some, several, these, various, most, other, those, smoker,
# Average loss at step 52000: 3.433602
# Average loss at step 54000: 3.424156
# Average loss at step 56000: 3.439146
# Average loss at step 58000: 3.398532
# Average loss at step 60000: 3.392813
# Nearest to war: jarring, match, loon, antiquaries, flakes, severus, luc, carriage,
# Nearest to its: their, his, her, the, heisei, ruse, aspirations, your,
# Nearest to been: become, be, previously, were, daring, had, gpcrs, was,
# Nearest to state: council, minas, hx, states, diverting, gens, county, economy,
# Nearest to this: it, which, there, that, the, some, sonatas, measurable,
# Nearest to they: we, there, you, he, she, these, i, idiopathic,
# Nearest to had: has, have, was, having, were, never, decided, saw,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to seven: eight, five, four, six, nine, three, zero, one,
# Nearest to at: in, courting, dilute, woogie, without, under, antikythera, extremist,
# Nearest to it: he, there, this, she, now, which, that, what,
# Nearest to was: is, had, became, were, has, when, although, though,
# Nearest to an: sheila, nw, godless, stretched, fiesole, jamahiriya, falsehoods, absalon,
# Nearest to most: more, many, some, stabilizing, hohlbein, hallucinogens, philosophical, criss,
# Nearest to from: into, through, redefine, in, presents, between, benign, bandar,
# Nearest to many: some, several, various, these, most, other, such, smoker,
# Average loss at step 62000: 3.243092
# Average loss at step 64000: 3.256522
# Average loss at step 66000: 3.400906
# Average loss at step 68000: 3.399712
# Average loss at step 70000: 3.354530
# Nearest to war: jarring, match, antiquaries, luc, plucking, severus, flakes, andrews,
# Nearest to its: their, his, the, her, our, heisei, wheelers, your,
# Nearest to been: become, be, were, daring, previously, was, sergey, existed,
# Nearest to state: states, council, city, county, minas, outings, guild, hx,
# Nearest to this: which, it, the, that, some, indymedia, there, another,
# Nearest to they: we, there, he, you, it, she, these, then,
# Nearest to had: has, have, was, were, having, saw, never, makes,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to seven: six, eight, nine, four, five, three, zero, one,
# Nearest to at: during, nearly, antikythera, around, meinhof, rf, near, on,
# Nearest to it: he, there, she, this, they, we, still, wang,
# Nearest to was: is, had, were, has, became, when, be, been,
# Nearest to an: gifford, sheila, nw, koontz, targets, absalon, falsehoods, contras,
# Nearest to most: more, many, some, less, hohlbein, hallucinogens, bremen, commando,
# Nearest to from: through, into, bandar, in, across, within, by, between,
# Nearest to many: some, several, various, these, most, all, such, those,
# Average loss at step 72000: 3.375715
# Average loss at step 74000: 3.343676
# Average loss at step 76000: 3.310784
# Average loss at step 78000: 3.348494
# Average loss at step 80000: 3.374751
# Nearest to war: jarring, match, luc, plucking, carriage, rhythm, severus, antiquaries,
# Nearest to its: their, his, her, the, our, your, ruse, heisei,
# Nearest to been: become, be, was, previously, existed, were, had, already,
# Nearest to state: states, council, county, city, press, outings, minas, hx,
# Nearest to this: which, it, the, that, indymedia, definitely, urging, weil,
# Nearest to they: we, he, there, you, she, it, these, wasting,
# Nearest to had: has, have, was, were, having, saw, been, became,
# Nearest to would: could, will, can, may, might, must, should, did,
# Nearest to seven: six, eight, four, five, nine, three, one, zero,
# Nearest to at: in, antikythera, woogie, once, during, around, nearly, without,
# Nearest to it: he, she, there, this, itself, they, effeminate, we,
# Nearest to was: is, became, were, had, has, been, becomes, being,
# Nearest to an: nw, sheila, gifford, flare, medici, pronouns, maureen, koontz,
# Nearest to most: more, many, some, less, hohlbein, hallucinogens, bahrain, resurfaced,
# Nearest to from: through, into, within, across, between, redefine, on, during,
# Nearest to many: some, several, various, these, most, those, both, all,
# Average loss at step 82000: 3.409971
# Average loss at step 84000: 3.414916
# Average loss at step 86000: 3.385219
# Average loss at step 88000: 3.352395
# Average loss at step 90000: 3.363278
# Nearest to war: jarring, antiquaries, match, appellate, rhythm, plucking, loon, luc,
# Nearest to its: their, his, her, the, your, our, wheelers, some,
# Nearest to been: become, be, already, previously, was, wildstorm, reflectors, had,
# Nearest to state: council, city, states, minas, gens, guild, county, theologian,
# Nearest to this: which, it, the, some, erasing, another, weil, definitely,
# Nearest to they: we, he, there, she, you, it, but, these,
# Nearest to had: has, have, was, were, having, decided, never, yet,
# Nearest to would: could, will, may, might, can, must, should, did,
# Nearest to seven: eight, six, four, nine, five, one, three, zero,
# Nearest to at: during, near, under, antikythera, while, in, meinhof, behind,
# Nearest to it: he, she, there, they, this, itself, often, arise,
# Nearest to was: is, had, were, became, has, be, been, being,
# Nearest to an: sheila, falsehoods, koontz, gifford, another, godless, nw, sylvia,
# Nearest to most: more, many, less, some, hohlbein, all, hallucinogens, commando,
# Nearest to from: through, into, during, between, across, redefine, within, before,
# Nearest to many: some, several, various, these, most, all, those, certain,
# Average loss at step 92000: 3.395520
# Average loss at step 94000: 3.258322
# Average loss at step 96000: 3.355960
# Average loss at step 98000: 3.241890
# Average loss at step 100000: 3.354913
# Nearest to war: match, jarring, appellate, saving, rhythm, metabolize, andrews, antiquaries,
# Nearest to its: their, his, her, the, your, our, wheelers, homicide,
# Nearest to been: become, be, already, was, previously, daring, wildstorm, sergey,
# Nearest to state: city, gens, states, council, minas, theologian, county, invites,
# Nearest to this: which, it, another, what, ding, weil, erasing, some,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to had: has, have, having, was, would, yet, were, decided,
# Nearest to would: could, will, might, can, may, should, must, cannot,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to at: during, on, under, near, antikythera, once, in, meinhof,
# Nearest to it: he, she, there, this, they, never, what, effeminate,
# Nearest to was: is, were, became, had, has, being, been, are,
# Nearest to an: disjunction, koontz, sheila, gifford, another, detours, jamahiriya, maureen,
# Nearest to most: more, many, less, some, hohlbein, commando, extremely, caption,
# Nearest to from: into, benign, through, within, redefine, in, after, lei,
# Nearest to many: several, some, various, these, those, numerous, all, most,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
from itertools import compress

data_index = 0

def generate_batch_CBOW(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    
    # Adapted from https://github.com/wangz10/tensorflow-playground/blob/master/word2vec.py#L105
    mask = [1] * span
    mask[skip_window] = 0 
    batch[i, :] = list(compress(buffer, mask))
    labels[i, 0] = buffer[skip_window]
    
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#
# with num_skips = 4 and skip_window = 2:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.015164
# Nearest to been: belong, dienes, ellis, goose, fever, scrapped, worcestershire, investigated,
# Nearest to d: pacing, gtpase, analgesic, mcenroe, coretta, saa, booker, dossier,
# Nearest to b: plumage, qh, later, reals, bugzilla, indulgent, wichita, spinoffs,
# Nearest to first: divx, tick, cloak, headstock, perkin, hummel, redirection, structures,
# Nearest to people: mermaid, zander, yehoshua, plummeted, el, lectured, torches, verrocchio,
# Nearest to most: hitting, gpcrs, aris, beverage, pampas, rye, cav, retrial,
# Nearest to about: sorbian, baseball, logudorese, heighten, annul, procedural, millionaire, emmett,
# Nearest to for: pulpit, yorktown, swapping, nisibis, phrased, inaccurately, exiles, gestis,
# Nearest to american: communicates, benedictine, daughters, galloping, reservoir, periodical, marshland, acuff,
# Nearest to will: romano, geological, cones, cornet, anyone, therefore, bhangra, brahui,
# Nearest to th: bee, eraserhead, change, lepidus, millikan, swore, rounding, chanted,
# Nearest to not: celibate, performs, shortens, dynasty, tapered, gatehouse, ticonderoga, dervish,
# Nearest to UNK: bai, backronym, inwo, laoco, sedan, appreciate, timed, academically,
# Nearest to that: springing, commentarii, marian, carotenoids, heineken, visual, rada, masturbate,
# Nearest to seven: whittaker, upu, aus, outlines, fasting, corsairs, repeats, jamaican,
# Nearest to time: melchior, revitalize, expropriated, ancestors, anthony, finals, gare, mutagenic,
# Average loss at step 2000: 4.092190
# Average loss at step 4000: 3.558473
# Average loss at step 6000: 3.388955
# Average loss at step 8000: 3.245486
# Average loss at step 10000: 3.179744
# Nearest to been: be, was, revolves, dienes, become, belong, navin, irregularly,
# Nearest to d: b, feldspar, failures, saa, mcenroe, rnir, camps, advantageous,
# Nearest to b: d, enciphered, mccoy, bounty, stella, bye, tyson, ji,
# Nearest to first: second, tick, redirection, rooks, gunner, franken, reaching, last,
# Nearest to people: zander, elie, jake, vibrant, averroes, ammonium, verrocchio, anticonvulsants,
# Nearest to most: some, more, many, pampas, rye, electroplating, cremona, roux,
# Nearest to about: sorbian, gunshot, frequency, supercontinent, logudorese, magnetometer, regnum, between,
# Nearest to for: burney, through, loosened, as, waffen, hallucination, townhouse, by,
# Nearest to american: british, kul, hurting, french, ect, kamchatka, english, pidgin,
# Nearest to will: would, can, may, could, must, heather, therefore, collectibles,
# Nearest to th: eraserhead, seven, swore, millikan, sauces, recalcitrant, lepidus, eight,
# Nearest to not: waite, nilo, now, also, to, never, gatehouse, kelly,
# Nearest to UNK: engrams, rangle, adversus, detergent, tonle, subproblems, pyrite, precisely,
# Nearest to that: which, motion, meridians, it, however, jamming, this, buns,
# Nearest to seven: eight, nine, six, three, four, five, zero, two,
# Nearest to time: recreate, itunes, motherland, schawlow, mojito, quick, platonism, anarchists,
# Average loss at step 12000: 3.202811
# Average loss at step 14000: 3.153602
# Average loss at step 16000: 3.176465
# Average loss at step 18000: 3.127928
# Average loss at step 20000: 2.997646
# Nearest to been: become, be, was, were, netsplit, rapidly, canetti, come,
# Nearest to d: b, feldspar, lodovico, ttt, saa, sybase, breaching, closeness,
# Nearest to b: d, mccoy, kwahu, linehan, bayes, dominates, catalans, anthologized,
# Nearest to first: second, last, rooks, franken, apple, final, sauces, amur,
# Nearest to people: zander, those, men, jennie, dialects, countries, fans, matchup,
# Nearest to most: more, some, many, jimmie, sale, less, roux, electroplating,
# Nearest to about: magnetometer, cocos, between, sorbian, coronary, alarmed, jarman, supercontinent,
# Nearest to for: hallucination, when, burney, paparazzi, through, anthropic, jacobs, sanchez,
# Nearest to american: french, ect, russian, asian, kamchatka, networks, english, british,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Nearest to th: swore, eraserhead, recalcitrant, ontology, eight, maneuver, five, four,
# Nearest to not: never, often, waite, nilo, generally, still, now, boastful,
# Nearest to UNK: overwhelmed, quaternary, tolstoy, gluconeogenesis, jackson, felice, chukotka, called,
# Nearest to that: which, however, this, involving, ethnocentric, jamming, saville, starvation,
# Nearest to seven: eight, five, six, four, nine, three, two, zero,
# Nearest to time: motherland, year, anarchists, recreate, platonism, half, padres, itunes,
# Average loss at step 22000: 3.079502
# Average loss at step 24000: 3.044277
# Average loss at step 26000: 3.001788
# Average loss at step 28000: 3.033236
# Average loss at step 30000: 3.001357
# Nearest to been: become, be, was, were, begun, come, neuronal, rapidly,
# Nearest to d: lodovico, b, n, feldspar, m, closeness, contracting, saa,
# Nearest to b: c, d, n, tubing, p, lili, shareware, motilal,
# Nearest to first: last, second, next, final, same, fifth, franken, yat,
# Nearest to people: men, those, women, others, countries, fans, zander, finkel,
# Nearest to most: some, more, many, jimmie, less, sale, use, unlicensed,
# Nearest to about: magnetometer, coronary, on, cocos, sorbian, nada, that, supercontinent,
# Nearest to for: without, kobayashi, dvb, technical, if, unbound, dislike, burney,
# Nearest to american: british, canadian, russian, french, german, asian, kinsmen, hurting,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to th: four, five, six, eraserhead, ontology, mirc, swore, recalcitrant,
# Nearest to not: still, never, now, waite, actually, almost, normally, generally,
# Nearest to UNK: renouf, ni, tribune, gluconeogenesis, symbiotic, sprite, relational, johnson,
# Nearest to that: which, however, this, what, about, schiavo, saville, steamboat,
# Nearest to seven: nine, four, six, eight, five, three, zero, two,
# Nearest to time: year, cryptosystems, motherland, period, ancestors, half, sons, disarray,
# Average loss at step 32000: 2.831151
# Average loss at step 34000: 2.951893
# Average loss at step 36000: 2.948919
# Average loss at step 38000: 2.941843
# Average loss at step 40000: 2.925360
# Nearest to been: become, be, were, was, flashbacks, begun, grown, neuronal,
# Nearest to d: b, feldspar, iowa, saa, ttt, contracting, n, lodovico,
# Nearest to b: d, n, c, f, lili, p, musicology, chiang,
# Nearest to first: last, second, same, final, next, fifth, third, ostracism,
# Nearest to people: men, women, those, countries, others, children, fans, jennie,
# Nearest to most: some, more, less, many, very, jimmie, sale, nynorsk,
# Nearest to about: approximately, magnetometer, coronary, fm, smoking, nada, kava, cocos,
# Nearest to for: when, after, underage, hallucination, if, cretaceous, bail, including,
# Nearest to american: british, canadian, russian, french, european, asian, german, kinsmen,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to th: fourth, cam, st, piero, abd, eraserhead, twentieth, mirc,
# Nearest to not: never, still, now, actually, always, waite, otherwise, nilo,
# Nearest to UNK: i, mechagodzilla, o, word, chieftain, homegrown, sedan, brigadists,
# Nearest to that: which, however, casta, what, where, consternation, owsley, saville,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to time: year, motherland, event, month, context, half, world, cryptosystems,
# Average loss at step 42000: 2.956778
# Average loss at step 44000: 2.959046
# Average loss at step 46000: 2.913295
# Average loss at step 48000: 2.866298
# Average loss at step 50000: 2.848893
# Nearest to been: become, be, grown, was, flashbacks, begun, were, already,
# Nearest to d: b, herding, lodovico, proprietor, robert, regulated, saa, fooled,
# Nearest to b: d, overline, musicology, mccoy, politician, hooper, bullough, chaplin,
# Nearest to first: last, second, next, final, fifth, same, third, fourth,
# Nearest to people: men, women, fans, those, individuals, children, jews, partner,
# Nearest to most: more, many, less, some, all, several, particularly, both,
# Nearest to about: approximately, coronary, cocos, fm, cram, magnetometer, casper, beaumont,
# Nearest to for: unbound, burney, cretaceous, when, if, operatic, despite, fanclub,
# Nearest to american: british, french, canadian, and, encodings, german, italian, russian,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to th: second, fourth, eraserhead, third, ontology, rd, nico, st,
# Nearest to not: now, never, generally, always, actually, still, otherwise, correspondingly,
# Nearest to UNK: chalmers, tolstoy, analysed, pinstripes, toaster, watkins, eth, li,
# Nearest to that: which, what, however, this, it, schiavo, everywhere, visually,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to time: year, motherland, sons, period, half, scratches, detective, itunes,
# Average loss at step 52000: 2.886776
# Average loss at step 54000: 2.867225
# Average loss at step 56000: 2.858756
# Average loss at step 58000: 2.746563
# Average loss at step 60000: 2.833949
# Nearest to been: be, become, grown, begun, were, gin, was, ever,
# Nearest to d: b, herding, lonesome, regulated, feldspar, lodovico, closeness, c,
# Nearest to b: d, c, overline, p, hooper, musicology, n, bullough,
# Nearest to first: last, second, next, final, third, fifth, same, amur,
# Nearest to people: men, women, fans, children, individuals, christians, those, xx,
# Nearest to most: some, many, more, especially, less, particularly, because, sale,
# Nearest to about: approximately, casper, cocos, concerning, hanks, coronary, cram, alarmed,
# Nearest to for: without, burney, after, cretaceous, before, swf, operatic, diarist,
# Nearest to american: british, canadian, australian, french, italian, german, russian, english,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to th: second, fourth, eighteenth, rd, nd, piero, twentieth, eraserhead,
# Nearest to not: never, now, still, otherwise, actually, usually, always, typically,
# Nearest to UNK: int, telescope, fatwas, archaeological, olds, crossover, lulach, yuen,
# Nearest to that: which, however, what, nicaea, saville, gunners, consternation, thus,
# Nearest to seven: five, six, four, nine, eight, three, zero, one,
# Nearest to time: motherland, period, year, sons, yearly, degree, cryptosystems, castillo,
# Average loss at step 62000: 2.837484
# Average loss at step 64000: 2.773239
# Average loss at step 66000: 2.762341
# Average loss at step 68000: 2.712566
# Average loss at step 70000: 2.783767
# Nearest to been: become, be, grown, begun, were, flashbacks, remained, gin,
# Nearest to d: b, regulated, proprietor, liquors, closeness, parisians, herding, overline,
# Nearest to b: d, overline, bullough, bayes, hooper, lodovico, objector, cassino,
# Nearest to first: second, last, next, fifth, third, final, best, same,
# Nearest to people: men, women, children, jews, individuals, fans, christians, countries,
# Nearest to most: more, less, many, some, sale, particularly, especially, highly,
# Nearest to about: concerning, over, approximately, cram, limb, alarmed, cocos, that,
# Nearest to for: after, despite, anthropic, tarleton, underage, tano, cretaceous, tome,
# Nearest to american: canadian, british, australian, italian, french, german, japanese, scottish,
# Nearest to will: would, must, can, could, should, may, might, cannot,
# Nearest to th: third, fourth, rd, eighteenth, ninth, nd, second, st,
# Nearest to not: never, always, now, actually, otherwise, usually, still, normally,
# Nearest to UNK: handlebar, tolstoy, visualizing, terminated, warhol, martha, bennett, iturbide,
# Nearest to that: which, however, what, where, gunners, about, bronzes, how,
# Nearest to seven: eight, five, six, nine, three, four, zero, two,
# Nearest to time: period, motherland, degree, belleville, cei, month, year, scratches,
# Average loss at step 72000: 2.800171
# Average loss at step 74000: 2.646493
# Average loss at step 76000: 2.804597
# Average loss at step 78000: 2.822599
# Average loss at step 80000: 2.778306
# Nearest to been: become, be, grown, begun, remained, already, were, flashbacks,
# Nearest to d: b, lou, closeness, parisians, saa, proprietor, sdlp, regulated,
# Nearest to b: d, overline, n, c, bullough, hooper, p, objector,
# Nearest to first: last, second, next, third, fifth, final, best, same,
# Nearest to people: women, men, children, fans, jews, persons, individuals, man,
# Nearest to most: many, more, some, sale, less, all, several, particularly,
# Nearest to about: approximately, concerning, over, limb, cram, viz, casper, syndicate,
# Nearest to for: after, when, without, paparazzi, including, during, while, although,
# Nearest to american: italian, australian, canadian, british, african, french, japanese, german,
# Nearest to will: would, could, can, must, should, might, may, cannot,
# Nearest to th: fourth, nd, six, eighteenth, rd, third, ninth, second,
# Nearest to not: never, actually, still, almost, normally, always, otherwise, theoretically,
# Nearest to UNK: chalmers, int, jpg, van, tolstoy, j, et, griffiths,
# Nearest to that: which, what, instead, however, how, everywhere, nicaea, this,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to time: period, degree, year, day, month, motherland, belleville, way,
# Average loss at step 82000: 2.666479
# Average loss at step 84000: 2.770969
# Average loss at step 86000: 2.733663
# Average loss at step 88000: 2.755457
# Average loss at step 90000: 2.733426
# Nearest to been: become, be, begun, grown, remained, were, already, gin,
# Nearest to d: b, catan, parisians, peacetime, t, lodovico, lou, ker,
# Nearest to b: d, c, overline, y, f, bullough, p, n,
# Nearest to first: last, second, next, third, fifth, earliest, final, previous,
# Nearest to people: women, men, children, jews, persons, fans, individuals, man,
# Nearest to most: more, many, some, less, sale, particularly, especially, both,
# Nearest to about: approximately, concerning, over, cram, around, cocos, casper, levers,
# Nearest to for: paparazzi, when, cleaved, turpentine, swf, despite, alienating, after,
# Nearest to american: australian, canadian, italian, african, british, french, scottish, indian,
# Nearest to will: would, could, can, should, must, might, cannot, may,
# Nearest to th: eighteenth, fourth, twentieth, nd, sixth, third, ninth, fifth,
# Nearest to not: never, actually, therefore, always, generally, now, normally, otherwise,
# Nearest to UNK: na, handlebar, diskettes, aurora, manzarek, tolstoy, wallace, ni,
# Nearest to that: which, what, however, this, emphatically, how, thus, where,
# Nearest to seven: eight, six, nine, four, five, zero, three, two,
# Nearest to time: month, degree, period, year, motherland, adventurers, day, cei,
# Average loss at step 92000: 2.676757
# Average loss at step 94000: 2.727190
# Average loss at step 96000: 2.702209
# Average loss at step 98000: 2.359197
# Average loss at step 100000: 2.402373
# Nearest to been: become, be, grown, begun, already, remained, come, flashbacks,
# Nearest to d: b, proprietor, offseason, axumite, viktor, patron, sdlp, polygamy,
# Nearest to b: d, overline, bullough, politician, journalist, pablo, longstreet, lodovico,
# Nearest to first: last, second, next, third, fifth, same, previous, final,
# Nearest to people: women, children, men, persons, jews, individuals, fans, man,
# Nearest to most: more, less, some, sale, many, especially, particularly, highly,
# Nearest to about: approximately, concerning, around, over, cram, syndicate, nada, scheldt,
# Nearest to for: after, without, usps, when, paparazzi, if, despite, against,
# Nearest to american: canadian, british, english, australian, italian, german, bipm, french,
# Nearest to will: would, could, should, can, might, must, cannot, may,
# Nearest to th: ninth, fifth, fourth, eighteenth, twentieth, sixth, nd, third,
# Nearest to not: never, actually, nothing, neither, always, theoretically, otherwise, you,
# Nearest to UNK: rosalynn, chalmers, pullman, handlebar, jones, rao, burlesque, sch,
# Nearest to that: which, what, however, privates, how, alludes, graceful, compassion,
# Nearest to seven: eight, five, four, nine, six, three, zero, two,
# Nearest to time: degree, period, month, day, year, motherland, phase, controversy,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
